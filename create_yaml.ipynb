# %%
import os
import yaml
import wandb
import json

# %%
model_name = "microsoft/Phi-3-mini-4k-instruct"
model_path = "/ceph/ssd/staff/schwinn/experiments/2025/capo_vlm/models/20241212161856/0/final_model"
experiment_id = "20241212161856"

# %% [markdown]
# # Create YAML file

# %%
model_path = "/ceph/ssd/staff/schwinn/experiments/2025/capo_vlm/models/20241212161856/0/final_model"
model_yamls_path = "/ceph/ssd/staff/schwinn/projects/25/llm-quick-check/conf/models/"

def create_yaml_for_run_attacks(model_path, config_path, experiment_id):
    model_config = json.load(open(os.path.join(model_path, "adapter_config.json")))
    model_name = model_config["base_model_name_or_path"]

    model_yamls_path = os.path.join(config_path, "models.yaml")
    with open(model_yamls_path, "r") as f:
        model_yamls = yaml.load(f, Loader=yaml.FullLoader)
    for m in model_yamls.keys():
        if m == model_name:
            model_yaml = {experiment_id:model_yamls[m]}
            model_yaml[experiment_id]["id"] = model_path
            model_yaml[experiment_id]["wandb_experiment_id"] = experiment_id
            new_model_file = os.path.join(config_path, experiment_id + ".yaml")
            with open(new_model_file, "w") as f:
                yaml.dump(model_yaml, f)	
            break
        
create_yaml_for_run_attacks(model_path, model_yamls_path, experiment_id)

# %%
log_path = "/ceph/ssd/staff/schwinn/experiments/2025/capo_vlm/attacks/attack_json/"
entity = "omega_alignment"
project = "vlm_icml_leo"

# %%
def log_to_wandb(log_path, entity, project):
    dates = os.listdir(log_path)
    for d in dates:
        date_times = os.listdir(os.path.join(log_path, d))
        for dt in date_times:
            run_json = os.path.join(log_path, d, dt, "run.json")
            if os.path.exists(run_json):
                with open(run_json, "r") as f:
                    run = yaml.load(f, Loader=yaml.FullLoader)
                    attack_name = run[0]["config"]["attack"]
                    model_params = run[0]["config"]["model_params"]
                    yes_no = run[0]["successes_cais"]
                    yes_no = [y[0].lower() for y in yes_no]
                    asr = yes_no.count("yes") / len(yes_no)
                         
                    experiment_id = model_params["wandb_experiment_id"].strip()
                    wandb.init(project=project, entity=entity, id=experiment_id, resume="allow")
                    wandb.log({f"asr_{attack_name}": asr})
                    wandb.finish()
                    print("Logged attack for " + experiment_id)
            else:
                print("No attack json found for " + experiment_id)
    print("Done logging to wandb")

# %%
log_to_wandb(log_path, entity, project)
# Out:
# 2
# wandb: ERROR Error while calling W&B API: run 20241212161856 was previously created and deleted; try a new run name (<Response [409]>)
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01111311071112545, max=1.0)…
# wandb: ERROR Error while calling W&B API: run 20241212161856 was previously created and deleted; try a new run name (<Response [409]>)
# wandb: ERROR Error while calling W&B API: run 20241212161856 was previously created and deleted; try a new run name (<Response [409]>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 log_to_wandb(log_path, entity, project)
#
# Cell In[30], line 18, in log_to_wandb(log_path, entity, project)
#      15 asr = yes_no.count("yes") / len(yes_no)
#      17 experiment_id = model_params["wandb_experiment_id"].strip()
# ---> 18 wandb.init(project=project, entity=entity, id=experiment_id, resume="allow")
#      19 wandb.log({f"asr_{attack_name}": asr})
#      20 wandb.finish()
#
# File /ceph/ssd/staff/schwinn/miniconda3/envs/capo_vlm/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:1171, in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, fork_from, resume_from, settings)
#    1169     wi = _WandbInit()
#    1170     wi.setup(kwargs)
# -> 1171     return wi.init()
#    1173 except KeyboardInterrupt as e:
#    1174     if logger is not None:
#
# File /ceph/ssd/staff/schwinn/miniconda3/envs/capo_vlm/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:747, in _WandbInit.init(self)
#     744 logger.info(f"communicating run to backend with {timeout} second timeout")
#     746 run_init_handle = backend.interface.deliver_run(run)
# --> 747 result = run_init_handle.wait(
#     748     timeout=timeout,
#     749     on_progress=self._on_progress_init,
#     750     cancel=True,
#     751 )
#     752 if result:
#     753     run_result = result.run_result
#
# File /ceph/ssd/staff/schwinn/miniconda3/envs/capo_vlm/lib/python3.12/site-packages/wandb/sdk/lib/mailbox.py:283, in MailboxHandle.wait(self, timeout, on_probe, on_progress, release, cancel)
#     280     if self._interface._transport_keepalive_failed():
#     281         raise MailboxError("transport failed")
# --> 283 found, abandoned = self._slot._get_and_clear(timeout=wait_timeout)
#     284 if found:
#     285     # Always update progress to 100% when done
#     286     if on_progress and progress_handle and progress_sent:
#
# File /ceph/ssd/staff/schwinn/miniconda3/envs/capo_vlm/lib/python3.12/site-packages/wandb/sdk/lib/mailbox.py:130, in _MailboxSlot._get_and_clear(self, timeout)
#     128 def _get_and_clear(self, timeout: float) -> Tuple[Optional[pb.Result], bool]:
#     129     found = None
# --> 130     if self._wait(timeout=timeout):
#     131         with self._lock:
#     132             found = self._result
#
# File /ceph/ssd/staff/schwinn/miniconda3/envs/capo_vlm/lib/python3.12/site-packages/wandb/sdk/lib/mailbox.py:126, in _MailboxSlot._wait(self, timeout)
#     125 def _wait(self, timeout: float) -> bool:
# --> 126     return self._event.wait(timeout=timeout)
#
# File /ceph/ssd/staff/schwinn/miniconda3/envs/capo_vlm/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /ceph/ssd/staff/schwinn/miniconda3/envs/capo_vlm/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# wandb: ERROR Error while calling W&B API: run 20241212161856 was previously created and deleted; try a new run name (<Response [409]>)
# wandb: ERROR Error while calling W&B API: run 20241212161856 was previously created and deleted; try a new run name (<Response [409]>)
# wandb: ERROR Error while calling W&B API: run 20241212161856 was previously created and deleted; try a new run name (<Response [409]>)
# wandb: ERROR Error while calling W&B API: run 20241212161856 was previously created and deleted; try a new run name (<Response [409]>)
