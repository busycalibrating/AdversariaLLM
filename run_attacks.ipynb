# %%
# Load the autoreload extension
# %load_ext autoreload

# Set autoreload to reload all modules (except those excluded by %aimport)
# %autoreload 2

# %%
# %run run_attacks.py --config-name="leo_config" attack_name="pgd" model_name='"2024-12-17-14-45-07"' models='"2024-12-17-14-45-07"'
# Out:
# [2024-12-17 14:56:30,958][HYDRA] Launching 1 jobs locally
# [2024-12-17 14:56:30,959][HYDRA] 	#0 : attack_name=pgd model_name="2024-12-17-14-45-07" models="2024-12-17-14-45-07"
# [2024-12-17 14:56:31,057][root][INFO] - -------------------
# [2024-12-17 14:56:31,057][root][INFO] - Commencing run `2024-12-17/14-56-31`
# [2024-12-17 14:56:31,058][root][INFO] - -------------------
# [2024-12-17 14:56:31,059][root][INFO] - Target: 2024-12-17-14-45-07
# chat_template: phi-3
# compile: false
# developer_name: Microsoft
# dtype: bfloat16
# id: /ceph/ssd/staff/schwinn/experiments/2025/capo_vlm/models/2024-12-17-14-45-07/0/final_model
# short_name: Phi
# tokenizer_id: microsoft/Phi-3-mini-4k-instruct
# trust_remote_code: false
# wandb_experiment_id: 2024-12-17-14-45-07
#
# ...

# %%
# %run run_judge.py --config-name="judge"
